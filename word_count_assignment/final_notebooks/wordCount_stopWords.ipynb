# %%
# %%writefile mapper.py
#!/usr/bin/env python2
import sys
import re

total_counter = 0
stop_counter = 0

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

with open('stop_words_en.txt', 'r') as stop_file:
    stop_words_str=stop_file.read()
stop_words_list = re.split('\n', stop_words_str, flags=re.UNICODE)

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    for word in words:
        total_counter += 1
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        if word.lower() in stop_words_list:
            stop_counter += 1
            print >> sys.stderr, "reporter:counter:Wiki stats,Stop words,%d" % 1

print "%s\t%d" % ("total", total_counter)
print "%s\t%d" % ("stop", stop_counter)
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/env python2
import sys

current_key = None
word_sum = 0

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print "%s\t%d" % (current_key, word_sum)
# Out:
# Overwriting reducer.py

# %%
# %%writefile reducer2.py

import sys

current_key = None
word_sum = 0
total_counter = 0
stop_counter = 0

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            if current_key == 'total':
                total_counter = word_sum
            elif current_key == 'stop':
                stop_counter = word_sum
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    if current_key == 'total':
        total_counter = word_sum
    elif current_key == 'stop':
        stop_counter = word_sum

print "%.2f" % (float((float(stop_counter) / total_counter)) * 100)
# Out:
# Writing reducer2.py

# %%
# %%bash
# INTERM_DIR="interm"
# OUT_DIR="wordcount_stopwords_result"
#
# hdfs dfs -rm -r -skipTrash ${INTERM_DIR} > /dev/null
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.job.name="Streaming wordCount stop words " \
#     -D mapreduce.job.reduces=2 \
#     -files mapper.py,/datasets/stop_words_en.txt,reducer.py \
#     -mapper "python mapper.py" \
#     -reducer "python reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${INTERM_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.job.name="Streaming wordCount stop words 2" \
#     -D mapreduce.job.reduces=1 \
#     -files reducer2.py \
#     -mapper "cat" \
#     -reducer "python reducer2.py" \
#     -input ${INTERM_DIR}/part-0000* \
#     -output ${OUT_DIR} > /dev/null
#
# hdfs dfs -cat ${OUT_DIR}/part-0000* | head
# Out:
# 41.60
# rm: `wordcount_stopwords_result': No such file or directory
# 17/11/12 11:48:42 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/11/12 11:48:43 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/11/12 11:48:45 INFO mapred.FileInputFormat: Total input files to process : 1
# 17/11/12 11:48:46 INFO mapreduce.JobSubmitter: number of splits:2
# 17/11/12 11:48:46 INFO Configuration.deprecation: mapred.job.name is deprecated. Instead, use mapreduce.job.name
# 17/11/12 11:48:46 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1510479432931_0003
# 17/11/12 11:49:03 INFO impl.YarnClientImpl: Submitted application application_1510479432931_0003
# 17/11/12 11:49:03 INFO mapreduce.Job: The url to track the job: http://4590f68e5114:8088/proxy/application_1510479432931_0003/
# 17/11/12 11:49:03 INFO mapreduce.Job: Running job: job_1510479432931_0003
# 17/11/12 11:49:41 INFO mapreduce.Job: Job job_1510479432931_0003 running in uber mode : false
# 17/11/12 11:49:41 INFO mapreduce.Job:  map 0% reduce 0%
# 17/11/12 11:50:10 INFO mapreduce.Job:  map 1% reduce 0%
# 17/11/12 11:50:22 INFO mapreduce.Job:  map 2% reduce 0%
# 17/11/12 11:50:34 INFO mapreduce.Job:  map 3% reduce 0%
# 17/11/12 11:50:47 INFO mapreduce.Job:  map 4% reduce 0%
# 17/11/12 11:50:58 INFO mapreduce.Job:  map 5% reduce 0%
# 17/11/12 11:51:10 INFO mapreduce.Job:  map 6% reduce 0%
# 17/11/12 11:51:17 INFO mapreduce.Job:  map 7% reduce 0%
# 17/11/12 11:51:35 INFO mapreduce.Job:  map 8% reduce 0%
# 17/11/12 11:51:42 INFO mapreduce.Job:  map 9% reduce 0%
# 17/11/12 11:51:53 INFO mapreduce.Job:  map 10% reduce 0%
# 17/11/12 11:52:05 INFO mapreduce.Job:  map 11% reduce 0%
# 17/11/12 11:52:18 INFO mapreduce.Job:  map 12% reduce 0%
# 17/11/12 11:52:30 INFO mapreduce.Job:  map 13% reduce 0%
# 17/11/12 11:52:41 INFO mapreduce.Job:  map 14% reduce 0%
# 17/11/12 11:52:53 INFO mapreduce.Job:  map 15% reduce 0%
# 17/11/12 11:53:05 INFO mapreduce.Job:  map 16% reduce 0%
# 17/11/12 11:53:13 INFO mapreduce.Job:  map 17% reduce 0%
# 17/11/12 11:53:30 INFO mapreduce.Job:  map 18% reduce 0%
# 17/11/12 11:53:36 INFO mapreduce.Job:  map 19% reduce 0%
# 17/11/12 11:53:48 INFO mapreduce.Job:  map 20% reduce 0%
# 17/11/12 11:54:00 INFO mapreduce.Job:  map 21% reduce 0%
# 17/11/12 11:54:19 INFO mapreduce.Job:  map 22% reduce 0%
# 17/11/12 11:54:31 INFO mapreduce.Job:  map 23% reduce 0%
# 17/11/12 11:54:37 INFO mapreduce.Job:  map 24% reduce 0%
# 17/11/12 11:54:49 INFO mapreduce.Job:  map 25% reduce 0%
# 17/11/12 11:55:01 INFO mapreduce.Job:  map 26% reduce 0%
# 17/11/12 11:55:13 INFO mapreduce.Job:  map 27% reduce 0%
# 17/11/12 11:55:31 INFO mapreduce.Job:  map 28% reduce 0%
# 17/11/12 11:55:38 INFO mapreduce.Job:  map 29% reduce 0%
# 17/11/12 11:55:50 INFO mapreduce.Job:  map 30% reduce 0%
# 17/11/12 11:56:02 INFO mapreduce.Job:  map 31% reduce 0%
# 17/11/12 11:56:14 INFO mapreduce.Job:  map 32% reduce 0%
# 17/11/12 11:56:26 INFO mapreduce.Job:  map 33% reduce 0%
# 17/11/12 11:56:37 INFO mapreduce.Job:  map 34% reduce 0%
# 17/11/12 11:56:50 INFO mapreduce.Job:  map 35% reduce 0%
# 17/11/12 11:57:02 INFO mapreduce.Job:  map 36% reduce 0%
# 17/11/12 11:57:14 INFO mapreduce.Job:  map 37% reduce 0%
# 17/11/12 11:57:20 INFO mapreduce.Job:  map 38% reduce 0%
# 17/11/12 11:57:32 INFO mapreduce.Job:  map 39% reduce 0%
# 17/11/12 11:57:44 INFO mapreduce.Job:  map 40% reduce 0%
# 17/11/12 11:57:56 INFO mapreduce.Job:  map 41% reduce 0%
# 17/11/12 11:58:07 INFO mapreduce.Job:  map 42% reduce 0%
# 17/11/12 11:58:20 INFO mapreduce.Job:  map 43% reduce 0%
# 17/11/12 11:58:32 INFO mapreduce.Job:  map 44% reduce 0%
# 17/11/12 11:58:44 INFO mapreduce.Job:  map 45% reduce 0%
# 17/11/12 11:58:51 INFO mapreduce.Job:  map 46% reduce 0%
# 17/11/12 11:59:08 INFO mapreduce.Job:  map 47% reduce 0%
# 17/11/12 11:59:14 INFO mapreduce.Job:  map 48% reduce 0%
# 17/11/12 11:59:26 INFO mapreduce.Job:  map 49% reduce 0%
# 17/11/12 11:59:39 INFO mapreduce.Job:  map 50% reduce 0%
# 17/11/12 11:59:51 INFO mapreduce.Job:  map 51% reduce 0%
# 17/11/12 12:00:03 INFO mapreduce.Job:  map 52% reduce 0%
# 17/11/12 12:00:15 INFO mapreduce.Job:  map 53% reduce 0%
# 17/11/12 12:00:27 INFO mapreduce.Job:  map 54% reduce 0%
# 17/11/12 12:00:39 INFO mapreduce.Job:  map 55% reduce 0%
# 17/11/12 12:00:51 INFO mapreduce.Job:  map 56% reduce 0%
# 17/11/12 12:01:03 INFO mapreduce.Job:  map 57% reduce 0%
# 17/11/12 12:01:15 INFO mapreduce.Job:  map 58% reduce 0%
# 17/11/12 12:01:27 INFO mapreduce.Job:  map 59% reduce 0%
# 17/11/12 12:01:40 INFO mapreduce.Job:  map 60% reduce 0%
# 17/11/12 12:01:52 INFO mapreduce.Job:  map 61% reduce 0%
# 17/11/12 12:01:58 INFO mapreduce.Job:  map 62% reduce 0%
# 17/11/12 12:02:16 INFO mapreduce.Job:  map 63% reduce 0%
# 17/11/12 12:02:22 INFO mapreduce.Job:  map 64% reduce 0%
# 17/11/12 12:02:39 INFO mapreduce.Job:  map 65% reduce 0%
# 17/11/12 12:02:51 INFO mapreduce.Job:  map 66% reduce 0%
# 17/11/12 12:02:58 INFO mapreduce.Job:  map 67% reduce 0%
# 17/11/12 12:03:04 INFO mapreduce.Job:  map 100% reduce 0%
# 17/11/12 12:03:21 INFO mapreduce.Job:  map 100% reduce 100%
# 17/11/12 12:03:22 INFO mapreduce.Job: Job job_1510479432931_0003 completed successfully
# 17/11/12 12:03:22 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=68
# 		FILE: Number of bytes written=419445
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=7
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=1600189
# 		Total time spent by all reduces in occupied slots (ms)=14532
# 		Total time spent by all map tasks (ms)=1600189
# 		Total time spent by all reduce tasks (ms)=14532
# 		Total vcore-milliseconds taken by all map tasks=1600189
# 		Total vcore-milliseconds taken by all reduce tasks=14532
# 		Total megabyte-milliseconds taken by all map tasks=1638593536
# 		Total megabyte-milliseconds taken by all reduce tasks=14880768
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=4
# 		Map output bytes=54
# 		Map output materialized bytes=74
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2
# 		Reduce shuffle bytes=74
# 		Reduce input records=4
# 		Reduce output records=1
# 		Spilled Records=8
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=6019
# 		CPU time spent (ms)=1146740
# 		Physical memory (bytes) snapshot=708460544
# 		Virtual memory (bytes) snapshot=5865693184
# 		Total committed heap usage (bytes)=497025024
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Stop words=4966319
# 		Total words=11937375
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=7
# 17/11/12 12:03:22 INFO streaming.StreamJob: Output directory: wordcount_stopwords_result
